# %%
import pandas as pd

df = pd.read_csv(r'./netflix_data.csv')
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
years = df[['release_year']]
duration = df[['duration']]
years, duration
type(years)
# Out:
# pandas.core.frame.DataFrame

# %%
movie_dict = dict(zip(years,duration))
movie_dict
# Out:
# {'y': 'd', 'e': 'u', 'a': 'r', 'r': 'a', 's': 't'}

# %%
import pandas as pd
df = pd.DataFrame(list(movie_dict.items()),columns=['years','durations'])
df
# Out:
#           years durations
# 0  release_year  duration

# %%
import matplotlib.pyplot as plt

df.plot(x=years,y=durations,kind='line')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 df.plot(x=years,y=durations,kind='line')
#       4 plt.show
#
# NameError: name 'durations' is not defined
